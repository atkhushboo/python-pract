# %%
def greet(fun):
    return "Hello",fun
print(greet("functions"))
# Out:
# ('Hello', 'functions')

# %%
def multiArgu(*arg):
    return arg
print(multiArgu(1))
print(multiArgu(1,2))
print(multiArgu(1,2,3))
# Out:
# (1,)
# (1, 2)
# (1, 2, 3)

# %%
# callin function in function

def greet(name):
    print("Hello",name,"!")
    
def main():
    print("main() function is calling")
    print(greet("Khushboo"))
main()
# Out:
# main() function is calling
# Hello Khushboo !
# None

# %%
# default arguments

def cal_area(lenght=12,widht=3):
    print("Arear of ractengal:- ",lenght*widht)

# not pass any argument    
cal_area()

# pass argument and it override and dont not matter the position of argument
cal_area(widht=4,lenght=5)

# passing only one argument
cal_area(lenght=7)
# Out:
# Arear of ractengal:-  36
# Arear of ractengal:-  20
# Arear of ractengal:-  21
