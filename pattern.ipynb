# %%
# print triangle

for i in range(1,5+1):

    print(" * "*i)
# Out:
#  *
#  *  *
#  *  *  *
#  *  *  *  *
#  *  *  *  *  *

# %%
row=5
for i in range(row,0,-1):
    print(" * "*i)
# Out:
#  *  *  *  *  *
#  *  *  *  *
#  *  *  *
#  *  *
#  *

# %%
# print k

row =5
col =5

for j in range(col,0,-1):
    print("*"," "*j,"*")

for i in range(0,row+1):
    print("*"," "*i,"*")
# Out:
# *       *
# *      *
# *     *
# *    *
# *   *
# *  *
# *   *
# *    *
# *     *
# *      *
# *       *

# %%
# print H

row=6

for i in range(0,row+1):
  print("*"," "*row," * ")

  if i==3:
    print("* "*row)
# Out:
# *         *
# *         *
# *         *
# *         *
# * * * * * *
# *         *
# *         *
# *         *
