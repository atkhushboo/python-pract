# %%
# print triangle

for i in range(1,5+1):

    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
row=5
for i in range(row,0,-1):
    print("*"*i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
row=10

for i in range(row,0,-1):
    # print("*"*i)add

    if i==10 :
        print(" i "* i)
    else:
        print("*")
# Out:
#  i  i  i  i  i  i  i  i  i  i
# *
# *
# *
# *
# *
# *
# *
# *
# *

# %%
# print k

row =5
col =5

for j in range(col,0,-1):
    print(" * "*j)

    

for i in range(0,row+1):
    print(" * "*i)
# Out:
#  *  *  *  *  *
#  *  *  *  *
#  *  *  *
#  *  *
#  *
#
#  *
#  *  *
#  *  *  *
#  *  *  *  *
#  *  *  *  *  *
