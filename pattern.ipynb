# %%
# print triangle

for i in range(1,5+1):

    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
row=5
for i in range(row,0,-1):
    print("*"*i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
row=10

for i in range(row,0,-1):
    # print("*"*i)add

    if i==10 :
        print(" i "* i)
    else:
        print("*")
# Out:
#  i  i  i  i  i  i  i  i  i  i
# *
# *
# *
# *
# *
# *
# *
# *
# *
