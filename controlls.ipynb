# %%
print("helo")

# %%
if( 2==3):
    print("heelo")
else:
    print("no heelo")
# Out:
# no heelo

# %%
email ="khush@gmil.com"
pasword ="123A2ul"

if(email==email):
    print("go to step 2")
    if(pasword==pasword):
        print("correct you're logged in")
    else:
        print("enter correcot pass")
else:
    print("enter correct id")
# Out:
# go to step 2
# correct you're logged in

# %%
email =input("enter your email")   "[[[[]]]]"
password =input("enter your password")

if("@" in email and ".com" in email):
 print("id is correct")
 if password.isdigit():
    print("correct")
 else:
     print("enter number")
else:
    print("enter @.com")
# Out:
# enter your email attiws@gmail.com
# enter your password 12344
# id is correct
# correct

# %%
score =
# Out:
# enter your score:  70
# fail

# %%
# // Write a C program to find maximum between three numbers.
def max_fun(a,b,c):
    # first find smaller
   if(a>b and a>c):
        return a

    if(b>c):
        return b
      return c
         
output = max_fun(13,13,13)
print(output)
# Out:
# 13

# %%
# // Write a C program to check whether a number is negative, positive or zero.

msg = {
  "po": "POSITIVE",
  "ne": "NEGATIVE",
  "ze": "ZERO"
}


def check_num():
    x =int(input("enter the number: "))

    if x<0:
        return msg['ne']

    if x==0:
        return msg['ze']

    if x>0:
        return msg['po']
         
    print("yess")

check_num()
# Out:
# enter the number:  34
# 'POSITIVE'

# %%
# // Write a C program to check whether a number is divisible by 5 and 11 or not.
def check_div():
    y=input("enter the number:")

    if isinstance(y,int):

     if int(y)%5==0 and int(y)%11==0:
      return "num is divisible"
     else:
      return "not divisivle"
    else:         
     return "entre the number please"

check_div()
# Out:
# enter the number: jh
# 'entre the number please'

# %%
# Write a C program to check whether a number is even or odd.

def even():
     x=input("enter the number")

     if int(x)%2==0:
      return "The Number is EVEN"
     else:
      return "The Number is ODD"

even()
# Out:
# enter the number 78
# 'The Number is EVEN'

# %%
# // Write a C program to check whether a year is leap year or not.
def leap():
    year=input("Enter the year")

    if int(year)%4==0 and int(year)%400==0:
        return "This is a Leap year"
    else:
        return "Not leap year"
leap()
# Out:
# Enter the year 2006
# 'Not leap year'

# %%
# // Write a C program to check whether a character is alphabet or not.

def char_alpha():
    x =input("Enter the character")
    y=ord(x)
    
    msg={
        "cp":"Capital Alphabet",
        "sm":"Small Alphabet",
        "sp":"Special Character"
    }
    
    print(y)
    if y>=65 and y<=90:
        return "This is " + msg['cp']


    if y>=97 and y<=112:
      return "This is " + msg['sm']

    return "This is " + msg['sp']

char_alpha()
# Out:
# Enter the character 8
# 56
# 'This is Special Character'

# %%
# // Write a C program to check whether a character is uppercase or lowercase alphabet.
def character_check():
    x=input("enter the character")
    y=ord(x)

    check={
        "up":"Upper Alphabet",
        "lo":"Lower Alphabet",
        "in": "Intiger Number"
    }

    if y>=65 and y<=90:
        return check['up']
    if y>=97 and y<=122:
        return check['lo']

    return check['in']
character_check()
# Out:
# enter the character h
# 'Lower Alphabet'

# %%
# // Write a C program to check whether a character is uppercase or lowercase alphabet.
def character_check():
    x=input("enter the character")
    y=ord(x)

    check={
        "up":"Upper Alphabet",
        "lo":"Lower Alphabet",
        "in": "Intiger Number"
    }

    if (x.isupper()):
        return check['up']
    
    
    if (x.islower()):
        return check['lo']

    return check['in']
character_check()
# Out:
# enter the character *
# 'Intiger Number'

# %%
# // Write a C program to input any character and check whether it is alphabet, digit or special character.
import re

def myCharCheckAscii(c):
        y =ord(c)
        if y>=65 and y<=90 or y>=97 and y<=122 :
            return 'Is AlphaBate'
        else:
            return 'Is Special Character'

def myRegexCheck(c):
    pattern = r"^[a-zA-Z]+$"
    if re.match(pattern, c):
       return 'Is AlphaBate'
    else:
       return 'Is Special Character'

def check_words():
    x=input("Enter a word")

    if(x.isdigit()) :
        return 'Is Number'
    else:
        return myRegexCheck(x)
    
    
check_words()
# Out:
# Enter a word 7
# 'Is Number'

# %%
# // Write a C program to input any character and check whether it is alphabet, digit or special character.
# cher=input("enter the word")
# print(cher.isalpha())

def check_alpha():
    strr=input("Enter the word")

    if strr.isalpha():
     return "its alphabet"
        
    if strr.isdigit():
     return "its Number"

    if strr.isalnum():
      return "its a alphanumeric"

    return "its special character"
     
check_alpha()
# Out:
# Enter the word c
# 'its alphabet'

# %%
# Write a python program to input any alphabet and check whether it is vowel or consonant.

def vowel():
    # user=input("enter the word")

    # if user=='a' or user=='e' or user=='i' or user=='o' or user=='u':
    #     return "Vowel"
        
    # return "Constant"

    vowell=['a','i','o','','u','e']
    user=input("enter the word")

    if user in vowell:
        return "Vowel"

    if user.isdigit():
         return "Enter the Character this is a Number"
        
    return "Constant"
          
vowel()
# Out:
# enter the word j
# 'Constant'

# %%
# .isascii check how to use  it return false when you type type in hindi or send emoji 

def check_ascci():
    y=input("enter the word")
    # char="a"

    if y.isascii():
      print("this is ascci")
        
    else:
        print("this is not Ascci this is a symbol  and hindi word")
check_ascci()
# Out:
# enter the word 😴
# this is not Ascci this is a symbol  and hindi word

# %%
# Find the factorial of a given number

def fact_num(n):

    if n < 0:
        return "The negative number is not exist for factorail"
    
    elif n == 0: 
        return 1
    else:
        fact =1

        for i in range(1,n+1):
            fact = fact*i
            
        return fact
output=fact_num(7)
print("the factorial number is",output)
# Out:
# the factorial number is 5040
