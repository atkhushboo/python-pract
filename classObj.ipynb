# %%
class Obj:

    def __init__(self,greet):
        self.greet=greet

my_obj = Obj("Hello OOPS") 
print(my_obj.greet)
# Out:
# Hello OOPS

# %%
class student:

    def __init__(self,name,age,course="null"):
        self.name=name
        self.age=age
        self.course=course

# instance or object
class_one = student("Khushboo",20,"MCA")
print(class_one.name,class_one.age,class_one.course)

class_two =student("Atul",21,"MCA")
print(class_two.name,class_two.age,class_two.course)

class_three =student("Khushi",19)
print(class_three.name,class_three.age)
# Out:
# Khushboo 20 MCA
# Atul 21 MCA
# Khushi 19

# %%
class Form:

    total_form=0
    def __init__(self,name,last_name,age):
        self.name= name
        self.last_name = last_name
        self.__age = age
        Form.total_form +=1
    


    # method that return full-name
    def full_name(self):
        return f"{self.name} {self.last_name}"
    
    # **************end*******
    @staticmethod
    def static_learn():
        return "Static method acces class & object without (self(object data))"
    
    @property
    def age(self):
        return self.__age
    
    # ******encapsulation*** to private attribute******** 
    def get__age(self):
        return self.__age,"!"
    
    # **********end******
    # ********polymorphism*********
    
    def topic(self):
        return "encapsulation-topic"
    
    # **************end**************

    # **************inheritance**********
class gender_sex(Form):
    def __init__(self,name,last_name,__age,gender):

        super().__init__(name,last_name,__age)
        self.gender=gender

    # ********polymorphism*********
    
    def topic(self):
        return "inheritance-topic"
    
    # *********end************
    
sex = gender_sex("khushi","kumari",19,"female")
print(sex.full_name(),sex.get__age(),sex.gender)
print(sex.topic())

# age is private attribute that's why we use get_age

# ****************end***********
    
    
first_form=Form("khushboo","kumari",20)
# first_form.age=19
print(first_form.topic())
print(Form.total_form)
print(first_form.static_learn())
print(Form.static_learn())
print(first_form.age)

# print(first_form.name)
# print(first_form.last_name)
# print(first_form.age)
# print(first_form.age())


# *************end*******
# method and self
# print(first_form.full_name())
# Out:
# khushi kumari (19, '!') female
# inheritance-topic
# encapsulation-topic
# 2
# Static method acces class & object without (self(object data))
# Static method acces class & object without (self(object data))
# 20

# %%
# bike class
class Bike:
    
    def __init__(self,brand,model):
        self.brand = brand
        self.__model = model

    # **********encapsulate**********hide data*****

    # def get_model(self):
    #     return self.__model
     
    # ************never change only for read ************    
    @property
    def modal(self):
        return self.__model

bike_one = Bike("hero","splender")
bike_one.model="activa"
print(bike_one.brand)
print(bike_one.modal())
# Out:
# hero
# splender

# %%
import math

class   Circle:

    def __init__(self,radius):
        self.radius = radius

    def get_area(self):
        return "Area of circle:-",math.pi*self.radius*self.radius
    
    def get_peramiter(self):
        return "Perameter of Circle:-",2*math.pi*self.radius
    
c_one = Circle(5)
print(c_one.get_area())
print(c_one.get_peramiter())
# Out:
# ('Area of circle:-', 78.53981633974483)
# ('Perameter of Circle:-', 31.41592653589793)

# %%
# example of class and object attributes

class Student:
    collage_Name ="Panjab University" #class attribute .........#use memory one time
    name ="khushi" 
    def __init__(self,name,course,marks): # use memory storage when ever the object created 
        self.name=name  # object attribute , object attributes > class attribute ............# object attribute always higher prefrence & priority in usesage 
        self.course=course 
        self.marks=marks

s1=Student("Khushboo","MCA",89) #object arguments pass 
print(Student.collage_Name) #class call
# print(Student.name) # class call
print(s1.name,s1.course,s1.marks) #object call
# Out:
# Panjab University
# Khushboo MCA 89

# %%
# create student class that take name and marks of 3 subject as a argument constructor. 
# then create a method to print average

class Student:
    def __init__(self,name,marks):
        self.name=name
        self.marks = marks

    @staticmethod
    def collage_name():
        return "Panjab University"
    
    def average(self):
        count =0
        arr =[]
        for i in range(len(self.marks)):
            arr.append(self.marks[i])
            count=count+1
            avg= sum(arr)/count
            
        return "the average number of",self.name,"is :-",avg
        
s1= Student("khushi",[90,45,85])
print(s1.collage_name())
# print(s1.name,s1.marks)
print(s1.average())

s2 = Student("khushbu",[98,99,97])
# print(s2.name,s2.marks)
print(s2.average())
# Out:
# Panjab University
# ('the average number of', 'khushi', 'is :-', 73.33333333333333)
# ('the average number of', 'khushbu', 'is :-', 98.0)

# %%
# importan topic
# Abstraction .........Hiding the unnaceccery details

class Car:

    def __init__(self):
        self.acc=False
        self.brk=False
        self.clutch=False
    
    def start(self):
        self.acc=True
        self.clutch=True

        print("Car is Started......")
    
    def stop (self):
        self.brk = True
        
        print("Car is stop.....")

carOne=Car()
carOne.start()
carOne.stop()
# Out:
# Car is Started......
# Car is stop.....

# %%
# create account class with 2 attribute balance and account number:
# create method for debit and credit and print balance:
    
class Account:
    def __init__(self,balance,account_no):
        self.balance=balance
        self.account_no=account_no
    
    def credit(self,amount):
        self.balance = self.balance + amount
        print(f"Credit in acount: {amount}")
        print(f"Updated balance: {self.balance}")
        
    def debit(self,amount):
        self.balance = self.balance - amount
        print("Debit from account:" ,amount)
        print("Current balance is: ",self.balance)
        
acc =Account(100,56783452)
print("Account Number is:" ,acc.account_no)
print("balance is: ",acc.balance)
acc.credit(5000)
acc.debit(2000)
# Out:
# Account Number is: 56783452
# balance is:  100
# Credit in acount: 5000
# Updated balance: 5100
# Debit from account: 2000
# Current balance is:  3100

# %%
# del keyword :- for delete object and its properties 

class Student:
    
    def __init__(self,name,age,roll_no):
        self.name = name
        self.age = age
        self.roll_no = roll_no
    
s1 = Student("khushi",18,3)
print(s1.name,s1.age,s1.roll_no)
del s1.age # del use to delete this attribute ...........
# print(s1.age)...........#deleted attribute 
print(s1.name,s1.roll_no)
# Out:
# khushi 18 3
# khushi 3

# %%
# private attribute and methods

class Login:

    def __init__(self,userName,password):
        self.userName= userName
        self.__password = password    #_ _ is private attribte
    
    def __secure_data(self):          #__ is private method 
        return "password is:-",self.__password
    
    def show_secure_data(self):        
        return self.__secure_data()       # call private method to call __password and print

userOne = Login("khush@123",70075)
print(userOne.userName)
print(userOne.show_secure_data())
print(userOne._Login__password) # hack type  but not recomended...........
# Out:
# khush@123
# ('password is:-', 70075)
# 70075

# %%
# inheritance : - inherit / drive the properties and method to the one class to another classs/

# single inheritance:-

class Mobile:
    
    @staticmethod
    def mobile_price():
        return "65000"
    
class Color(Mobile):     #single inheritance

    def __init__(self,colors):
        self.colors = colors

class Brand(Color): #multi-level inheritance.......
    
    def __init__(self,name,colors):
        super().__init__(colors)   #use to inherite /acces the method of parent class.......
        self.name=name

class Country(Brand):

    @staticmethod
    def country():
        return "USA"
    

# mobile_one = Color ("White")
# print(mobile_one.mobile_price())
# print(mobile_one.colors)  
# b1 = Brand("iphone","White")
# print(b1.mobile_price())
# print(b1.colors)
cn = Country("iphone","white")
print(cn.name,cn.colors,cn.mobile_price(),cn.country())
# Out:
# iphone white 65000 USA

# %%
# multiple inheritance

class First:
    
    @staticmethod
    def section_A():
        return "Section -A"

class Second:
    
    @staticmethod
    def section_B():
        return "Section -B"
    
class Third:

    @staticmethod
    def student():
        return "Khushboo and Khushi"

class College(First,Second,Third):
    
    @staticmethod
    def college():
        return "Panjab university"

c1 = College()
print(c1.section_A(),c1.section_B(),c1.student(),c1.college())
# Out:
# Section -A Section -B Khushboo and Khushi Panjab university

# %%
# Hierarchical inheritence test case only  
# note:- Cat == Dog == Animals ......WORK ,
# BUT If Cat == Animals == Dog ..........NOT WORK 

class Animals:
    
    @staticmethod
    def parent():
        return "Animals is here..."

class Dog(Animals):

    def child_a(self):
        return "Dog's are here..."

class Cat(Animals): #...........multiple childs

    def chile_b(self):
        return "Cat's are here...."
    
c1 = Cat()
print(c1.parent())
print(c1.chile_b())
# print(c1.child_a()) .......not able to access dog class
# Out:
# Animals is here...
# Cat's are here....

# %%
# CASE TO CHANGE IN OBJECT/Method DIRECT CLASS ATTRIBUTE

class Person:

    name = "anonymous"
 
    def changeName(self,name):
        # self.name = name  #only change in object/Method becouse it create a new name attribute...

        # Person.name = name # First way to change direct in Main Class
        self.__class__.name = name  # Second way to change 

p1 = Person()
p1.changeName("khushii")
print(p1.name) 

print(Person.name)
# Out:
# khushii
# khushii

# %%
# classmethod decorator

class Person:
    
    name ="anonymous"

    @classmethod #use to change attribute in Parent class
    def change_Name(cls,name):
        cls.name = name
    
p1 = Person()
p1.change_Name("Khushbu")
print(p1.name)
print(Person.name)
# Out:
# Khushbu
# Khushbu

# %%
# property method


class Student:

    def __init__(self,py,math,java):
        self.py = py
        self.math = math
        self.java = java
        # self.cal_mark = (self.py + self.math + self.java) /3
    

    # def cal_percentage(self):
        # self.persantage = str((self.py + self.math + self.java) /3 )+'%'

    @property  #use as a attribute in class / object/etc
    def percantage(self):
        return str((self.py + self.math + self.java) /3 )+'%'


st = Student(78,98,77)

# st.cal_percentage()
print(st.percantage)
st.py=98
print(st.py)
# st.cal_percentage()
print(st.percantage)
# Out:
# 84.33333333333333%
# 98
# 91.0%

# %%
# polymorphism : operator overloading
# print(1+2)
# print("khush" +"boo")
# print([1,2,3,4]+[5,6,7,8]) ........operator overloading 

#simple test case .............

class Dog:

    def sound(self):
        return "Bark..."
    
class Cat:

    def sound(self):
        return "Meoww..."
    
def makesounds(animal):
    print(animal.sound())

makesounds(Dog())
makesounds(Cat())
# Out:
# Bark...
# Meoww...

# %%
# test-case-of-complexNum...
#using Dunder function

class complex:

    def __init__(self,real,img):
        self.real = real
        self.img =img

    def showNum(self):
        print(self.real,"i +", self.img,"j")

    def __add__(self,obj2):      #using dundur function __add__
        newReal = self.real + self.real
        newImg = self.img + self.img
        return complex(newReal,newImg)

num1 = complex(5,8)
num2 = complex(7,8)
num1.showNum()
num2.showNum()
result = num1 + num2
result.showNum()
# Out:
# 5 i + 8 j
# 7 i + 8 j
# 10 i + 16 j

# %%
# Test-case-inherit property from employe class to Enginer class with additional attribute 

class Empl:
    
    def __init__(self,role,dept,sal):
        self.role = role
        self.dept = dept
        self.sal = sal 
    
    # def showDetail(self):
    #     return self.role,self.dept,self.sal 

class Enginer(Empl):  #inherite Empl class
    
    def __init__(self,name,age,role,dept,sal):
        self.name= name
        self.age = age
        super().__init__(role,dept,sal)   # use Super() to inherite __init__property
        
    def showDetails(self):
        return  self.name,self.age,self.role,self.dept,self.sal 
    
    
e1 = Enginer("Khush",19,"Python Developer","BeckEnd",4.8)
print(e1.showDetails())
